# %% [markdown]
# <a href="https://colab.research.google.com/github/trisha123789/HOUSE_RENT_PREDICTION/blob/main/House_rent_prediction_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING THE NECESSARY LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# LOAD THE DATASET

# %%
data = pd.read_csv('/content/House_Rent_Dataset.csv')

# %%
data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# VIEW TOP ROWS

# %%
data.head(5)
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
data.tail(5)
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741  2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
data.dtypes
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type            object
# Area Locality        object
# City                 object
# Furnishing Status    object
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object

# %%
data.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# CHECK TOTAL NUMBER OF MISSING VALUES

# %%
data.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %% [markdown]
# CHANGING THE DATA TYPE OF BATHROOM

# %%
data['Bathroom'] = data['Bathroom'].astype('object')

# %%
data.dtypes
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type            object
# Area Locality        object
# City                 object
# Furnishing Status    object
# Tenant Preferred     object
# Bathroom             object
# Point of Contact     object
# dtype: object

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# DROP ALL THE ROWS CONTAINING MISSING VALUES

# %%
data.dropna(inplace = True)

# %% [markdown]
# VIEW THE COUNT OF ROWS WHICH ARE DUPLICATE ROWS

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Posted On, BHK, Rent, Size, Floor, Area Type, Area Locality, City, Furnishing Status, Tenant Preferred, Bathroom, Point of Contact]
# Index: []

# %% [markdown]
# DELETING THE ROWS HAVING DUPLICATED VALUES

# %%
data.drop_duplicates()
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# EDA

# %% [markdown]
# univariate analysis

# %%
plt.figure(figsize = (9,8))
plt.plot(data['Rent'],color ='red',label='rent analysis')
plt.show()

# %% [markdown]
# OUTLIER DETECTION

# %%
plt.figure(figsize = (9,8))
sns.boxplot(data = data,x='Rent')
plt.title('OUTLIER DETECTION')
plt.show()

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x ='Size',y='Rent',data = data)
plt.title('RENT VS SIZE')
plt.show()

# %%
data['Bathroom'] = data['Bathroom'].astype('int')

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x ='Bathroom',y='Rent',data = data)
plt.title('RENT VS SIZE')
plt.show()

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
numerical_columns = data.select_dtypes(include = ['int64','float64'])
corr = numerical_columns.corr()
plt.figure(figsize = (9,8))
sns.heatmap(corr,annot = True,cmap = "magma")
plt.title("correlation between numerical columns")
plt.show()

# %%
sns.pairplot(numerical_columns,hue='Rent')

# %% [markdown]
# MACHINE LEARNING PART - CREATING SIMPLE LINEAR REGRESSION MODEL AND ALSO REGRESSION METRICS

# %%
data.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
X = data.iloc[:,3].values

# %%
X
# Out:
# array([1100,  800, 1000, ..., 1750, 1500, 1000])

# %%
y = data.iloc[:,2].values

# %%
#splitting into testing and training variables
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
len(X_train)
# Out:
# 3796

# %%
len(X_test)
# Out:
# 950

# %%
len(y_train)
# Out:
# 3796

# %%
len(y_test)
# Out:
# 950

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

y_train = y_train.reshape(-1,1)

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.figure(figsize=(9,9))
plt.plot(y_pred,color = 'Blue',label = 'predict')
plt.plot(y_test,color = 'red',label = 'test')
plt.show()

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 2140969927.9618244

# %%
r2 = r2_score(y_test,y_pred)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2140969927.9618244

# %%
#calculating r2_adjacent
n = X_test.shape[0]
k = X_test.shape[1]
r2_adj = 1 - (1-r2) *(n-1)/(n-1-k)

# %%
print(r2_adj)
# Out:
# 0.2819576591942822
